# %%
# opencv 4.1.2 to read images
import cv2

# used for accessing url to download files
import urllib.request as urlreq

# used to access local directory
import os

# used to plot our images
import matplotlib.pyplot as plt

# used to change image size
from pylab import rcParams

# %%
pic = "D:/to_distribute/001-02/left_0.png"
# read image with openCV
image = cv2.imread(pic)

# plot image with matplotlib package
plt.imshow(image)

# %%
haarcascade = "haarcascade_frontalface_alt2.xml"

# create an instance of the Face Detection Cascade Classifier
detector = cv2.CascadeClassifier(haarcascade)

# Detect faces using the haarcascade classifier on the "grayscale image"
faces = detector.detectMultiScale(image)

# Print coordinates of detected faces
print("Faces:\n", faces)
# Out:
# Faces:
#  [[267 201 198 198]]

# %%
for face in faces:
#     save the coordinates in x, y, w, d variables
    (x,y,w,d) = face
    # Draw a white coloured rectangle around each face using the face's coordinates
    # on the "image_template" with the thickness of 2 
    cv2.rectangle(image,(x,y),(x+w, y+d),(255, 255, 255), 2)

plt.axis("off")
plt.imshow(image)
plt.title('Face Detection')
# Out:
# Text(0.5, 1.0, 'Face Detection')

# %%
# save facial landmark detection model's name as LBFmodel
LBFmodel = "LFBmodel.yaml"

# create an instance of the Facial landmark Detector with the model
landmark_detector  = cv2.face.createFacemarkLBF()
landmark_detector.loadModel(LBFmodel)

# Detect landmarks on "image_gray"
_, landmarks = landmark_detector.fit(image, faces)

# print coordinates of detected landmarks
print("landmarks LBF\n", landmarks)

id = 0
for landmark in landmarks:
    for x,y in landmark[0]:
        cv2.circle(image, (int(x), int(y)), 1, (255, 255, 255), 1)
        print (id)
        cv2.putText(image, str(id), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    id +=1
plt.imshow(image)
# Out:
# landmarks LBF
#  (array([[[279.4141 , 282.52835],
#         [281.76776, 305.09354],
#         [286.2341 , 327.0945 ],
#         [292.14694, 349.41913],
#         [302.36075, 368.7355 ],
#         [315.89206, 385.03363],
#         [332.4729 , 398.34335],
#         [351.104  , 408.2455 ],
#         [371.53778, 409.92123],
#         [390.51938, 405.69275],
#         [405.26462, 393.11404],
#         [417.85837, 377.4441 ],
#         [428.50616, 359.5498 ],
#         [435.6766 , 339.32483],
#         [439.73172, 317.55685],
#         [441.6056 , 295.6999 ],
#         [440.45132, 273.5237 ],
#         [292.58356, 270.15863],
#         [302.9687 , 256.74396],
#         [320.8754 , 252.39027],
#         [339.14285, 254.61676],
#         [355.72397, 261.99686],
#         [378.17758, 261.60587],
#         [393.2166 , 254.57831],
#         [408.69156, 250.35153],
#         [424.45108, 252.87791],
#         [433.64035, 264.24255],
#         [367.69254, 276.7234 ],
# ...

# %%
pic = "D:/to_distribute/001-02/left_0.png"
# read image with openCV
image = cv2.imread(pic)

# create an instance of the Facial landmark Detector with the model
landmark_detector  = cv2.face.createFacemarkLBF()
landmark_detector.loadModel(LBFmodel)

# Detect landmarks on "image_gray"
_, landmarks = landmark_detector.fit(image, faces)

selected_indices = [18, 21, 22, 26, 36, 39, 42, 45, 0, 30, 16, 48, 54, 8]
selected_landmarks = [landmarks[0][0][i] for i in selected_indices]

for landmark in selected_landmarks:
    x, y = landmark
    cv2.circle(image, (int(x), int(y)), 2, (255, 255, 255), 2)

print(selected_landmarks)
plt.imshow(image)
# Out:
# [array([301.4614, 255.1631], dtype=float32), array([350.7472 , 260.73337], dtype=float32), array([375.90305, 260.74487], dtype=float32), array([433.6322 , 262.79846], dtype=float32), array([309.39688, 280.37363], dtype=float32), array([342.9928 , 283.77982], dtype=float32), array([385.97806, 283.52277], dtype=float32), array([418.13785, 279.18835], dtype=float32), array([277.7582, 284.5506], dtype=float32), array([369.52188, 327.25076], dtype=float32), array([441.7728 , 275.64395], dtype=float32), array([335.55984, 362.39835], dtype=float32), array([397.06448, 362.25967], dtype=float32), array([368.9491 , 411.08658], dtype=float32)]

# %%
len(selected_landmarks)
# Out:
# 14
